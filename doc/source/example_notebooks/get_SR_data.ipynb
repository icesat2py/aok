# %% [markdown]
# # Get Data via SlideRule (SR)
#
# Obtain data needed for Kd computation using SlideRule

# %% [markdown]
# Note: A generalized read-in function, along with a copy of the original function used by Chao to read in data, is located in the icepyx readdev.py file, imported locally below.

# %%
# not sure if this is needed anymore; restart kernel after running
# %pip install --upgrade sliderule
# Out:
# ...
#   Using cached sliderule-5.3.1-py3-none-any.whl.metadata (865 bytes)
# ...
# Using cached sliderule-5.3.1-py3-none-any.whl (178 kB)
# ...
#   Attempting uninstall: sliderule
#     Found existing installation: sliderule 4.20.0
#     Uninstalling sliderule-4.20.0:
#       Successfully uninstalled sliderule-4.20.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import glob

# %load_ext autoreload
import icepyx as ipx
# %autoreload 2
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0ea1b25a-0533-4665-9593-59cd5fc0af35'>
#   <div id="b7b29c54-518d-4fa7-9711-4b458a252ab7" data-root-id="0ea1b25a-0533-4665-9593-59cd5fc0af35" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
from datetime import datetime, timedelta
import time

import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import rasterio as rio
from rasterio.session import AWSSession
from shapely.geometry import Polygon
import xarray as xr

import boto3
import earthaccess
import icepyx as ipx
from sliderule import sliderule, icesat2 #, io

# %%
# Get some sample data (if don't already have it)

spatial_extent = [39.6, -76.9, 37.3, -75.6]
short_name = 'ATL03'
temporal = [datetime(2020, 3, 15, 6),datetime(2020, 3, 15, 9)]
region = ipx.Query(short_name, spatial_extent, temporal, start_time="06:00:00", end_time="09:00:00")

# %%
# this could be a bogus extent - need to confirm it's right
srextent = [
        {
            "lon": spatial_extent[1],
            "lat": spatial_extent[0]
        },
        {
            "lon": spatial_extent[3],
            "lat": spatial_extent[0]
        },
        {
            "lon": spatial_extent[3],
            "lat": spatial_extent[2]
        },
        {
            "lon": spatial_extent[1],
            "lat": spatial_extent[2]
        },
        {
            "lon": spatial_extent[1],
            "lat": spatial_extent[0]
        }
    ]

# %%
srextent
# Out:
# [{'lon': -76.9, 'lat': 39.6},
#  {'lon': -75.6, 'lat': 39.6},
#  {'lon': -75.6, 'lat': 37.3},
#  {'lon': -76.9, 'lat': 37.3},
#  {'lon': -76.9, 'lat': 39.6}]

# %%
region.avail_granules(ids=True)
# Out:
# [['ATL03_20200315055234_12140610_007_01.h5',
#   'ATL03_20200315060558_12140612_007_01.h5',
#   'ATL03_20200315072651_12150610_007_01.h5',
#   'ATL03_20200315074015_12150612_007_01.h5']]

# %%
region.avail_granules(cycles=True, tracks=True)
# Out:
# [['06', '06', '06', '06'], ['1214', '1214', '1215', '1215']]

# %%
from icepyx.core.variables import Variables as Variables
from icepyx.core.variables import list_of_dict_vals

# %%
reader = ipx.Read(data_source=path_root+"/*ATL03*")
reader.filelist
# Out:
# ['/Users/jessica/computing/icepyx/test_data/aok/102341461_ATL03_20200315074015_12150612_006_01_subsetted.h5',
#  '/Users/jessica/computing/icepyx/test_data/aok/102341460_ATL03_20200315072651_12150610_006_01_subsetted.h5',
#  '/Users/jessica/computing/icepyx/test_data/aok/102341459_ATL03_20200315060558_12140612_006_01_subsetted.h5',
#  '/Users/jessica/computing/icepyx/test_data/aok/102341458_ATL03_20200315055234_12140610_006_01_subsetted.h5']

# %%
avail = reader.variables.avail()
avail

# %%
reader.variables.wanted

# %%
vars=Variables(product='ATL03')
# vars.avail(options=True)
# Out:
# var_list inputs: atl03_pad, band_tol, min_full_sat, min_knn, min_near_sat, min_sat_h, min_scan_s, ph_sat_flag, ph_sat_lb, ph_sat_ub, podppd_pad, scan_settle_s, win_h, win_x, det_ab_flag, ds_gt, ds_stat, hvpc_ab_flag, laser_12_flag, lrs_ab_flag, pdu_ab_flag, ph_uncorrelated_error, rx_bckgrd_sensitivity, rx_return_sensitivity, spd_ab_flag, tams_ab_flag, tx_pulse_distribution, tx_pulse_energy, tx_pulse_skew_est, tx_pulse_thresh_lower, tx_pulse_thresh_upper, tx_pulse_width_lower, tx_pulse_width_upper, atlas_sdp_gps_epoch, cal42_product, dead_time, sigma, side, temperature, cal34_product, rad_corr, strength, width, ds_channel, cal19_product, ffb_corr, bin_width, cal20_product, hist, total_events, hist_x, laser, mode, num_bins, return_source, control, data_end_utc, data_start_utc, end_cycle, end_delta_time, end_geoseg, end_gpssow, end_gpsweek, end_orbit, end_region, end_rgt, granule_end_utc, granule_start_utc, addpad_flag, alpha_inc, alpha_max, delta_t_gap_min, delta_t_lin_fit, delta_t_max
# ...

# %%
variables = Variables(product='ATL03')
# try an approach without specifying specific variables, only beams and groups
variables.append(keyword_list=['geolocation', 'heights', 'bckgrd_atlas', 'geophys_corr', # ai generated as needed for AOK
                               "atlas_impulse_response", "orbit_info"], # needed to get keys to match
                      beam_list=['gt1l', 'gt1r', 'gt2l', 'gt2r', 'gt3l', 'gt3r'])
# CRITICAL: there's an issue with not being able to selectively add/remove data that is less nested, 
# i.e. ancillary_data.gt1r (that or it's being read in/added via the variables path/group parsing)
variables.append(keyword_list=["ancillary_data"])

# %%
variables.wanted

# %% [markdown]
# ## Get data with SlideRule

# %%
# Initialize SlideRule client
sliderule.init("slideruleearth.io")
# Out:
# True

# %%
# Build ATL03 Request
parms = {
    "poly": srextent,
    "t0": f'{temporal[0]:%Y-%m-%dT%H:%M:%SZ}',
    "t1": f'{temporal[1]:%Y-%m-%dT%H:%M:%SZ}',
    "srt": [0,1,2,3,4],
    "cnf": [-2, -1, 0, 1, 2, 3, 4],
    "output": {
        "path": "kdOutputAsGeo.geoparquet",
        "format": "parquet",
        "as_geo": True,
        "open_on_complete": True
    }
}

# %%
# Latch Start Time
perf_start = time.perf_counter()

# https://docs.slideruleearth.io/api_reference/icesat2.html
# Request ATL03 Data
yapc_sr = icesat2.atl03sp(parms) #, resources=grans)

# Latch Stop Time
perf_stop = time.perf_counter()

# %%
# Display Statistics
perf_duration = perf_stop - perf_start
print("Completed in {:.3f} seconds of wall-clock time".format(perf_duration))
print("Reference Ground Tracks: {}".format(yapc_sr["rgt"].unique()))
print("Cycles: {}".format(yapc_sr["cycle"].unique()))
print("Received {} elevations".format(yapc_sr.shape[0]))
# Out:
# Completed in 0.338 seconds of wall-clock time
# Reference Ground Tracks: []
# Cycles: []
# Received 0 elevations

# %% [markdown]
# Expected Tracks: 1214, 1215
# Expected Cycles: 06

# %% [markdown]
# ## Plot SR Results

# %%
f, ax = plt.subplots()
ax.set_title("SR Points")
ax.set_aspect('equal')
yapc_sr.plot(ax=ax, column='h_mean', cmap='inferno', s=0.1)
# ax.plot([pt["lon"] for pt in extent], [pt["lat"] for pt in extent], linewidth=1, color='g')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 ax.set_title("SR Points")
#       3 ax.set_aspect('equal')
# ----> 4 yapc_sr.plot(ax=ax, column='h_mean', cmap='inferno', s=0.1)
#       5 # ax.plot([pt["lon"] for pt in extent], [pt["lat"] for pt in extent], linewidth=1, color='g')
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/geopandas/plotting.py:962, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     960 kind = kwargs.pop("kind", "geo")
#     961 if kind == "geo":
# --> 962     return plot_dataframe(data, *args, **kwargs)
#     963 if kind in self._pandas_kinds:
#     964     # Access pandas plots
#     965     return PlotAccessor(data)(kind=kind, **kwargs)
#
# ...

# %%
# Execute request (returns file path when output format is specified)
output_file = sliderule.run("atl03x", parms)
print(f"Data saved to: {output_file}")
# Out:
# Data saved to:                                region  gt  spacecraft_velocity  \
# time_ns
# 2023-11-22 02:14:32.671240448      12  60          7060.858887
# 2023-11-22 02:14:32.673640704      12  60          7060.858887
# 2023-11-22 02:14:32.674140672      12  60          7060.858398
# 2023-11-22 02:14:32.707740672      12  60          7060.859863
# 2023-11-22 02:14:32.710340608      12  60          7060.860352
# ...                               ...  ..                  ...
# 2023-11-16 13:59:58.060982272      10  10          7067.642578
# 2023-11-16 13:59:58.060982272      10  10          7067.642578
# 2023-11-16 13:59:58.061182208      10  10          7067.642578
# 2023-11-16 13:59:58.061482240      10  10          7067.642578
# 2023-11-16 13:59:58.061682176      10  10          7067.642578
#
#                                solar_elevation  yapc_score  rgt  ph_index  \
# time_ns
# 2023-11-22 02:14:32.671240448        -5.834347          90  978   5119761
# ...

# %%
# Read the output file into a GeoDataFrame
output_file = sliderule.run("atl03x", parms)
gdf = gpd.read_parquet(output_file)
